# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('LabeledTweetsIDSample2000.csv')

# %%
data.head(15)
# Out:
#                      id  label
# 0   1234837799045562370     -1
# 1   1234837796248002560      0
# 2   1234837793152667648      0
# 3   1234837791588089856      0
# 4   1234837787913969669     -1
# 5   1234837787309940736      0
# 6   1234837785598713863      1
# 7   1234837784273313793      0
# 8   1234837783883239425      0
# 9   1234837783820357632     -1
# 10  1234837781979029505      0
# 11  1234837776702607367     -1
# 12  1234837775674957824      1
# 13  1234837775607836676     -1
# 14  1234837766132969472      0

# %%
sns.heatmap(data.isnull(), cmap='viridis')
plt.figure(figsize=(8,6))
data.isnull().sum()
# Out:
# id       0
# label    0
# dtype: int64

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8, 6))
ax=sns.countplot(data['label'])
ax.set_xticklabels(['Correct Information', 'unrelated content','False Information'])
# Out:
# C:\Users\temil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Correct Information'),
#  Text(1, 0, 'unrelated content'),
#  Text(2, 0, 'False Information')]

# %%
df = data.groupby('label').size()

# Make the plot with pandas
df.plot(kind='pie', subplots=True, figsize=(8, 8))
plt.title("Pie Chart of Label Class - Bad")
plt.ylabel("")
plt.show()
